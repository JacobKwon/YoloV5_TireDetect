# %% [markdown]
# # Reference

# %% [markdown]
# https://velog.io/@larsien/YoloV5-%EC%82%AC%EB%9E%8C%EB%A7%8C-%EC%B0%BE%EC%95%84%EB%B3%B4%EC%9E%90<br>
# https://velog.io/@dntjr1234/Yolov5%EB%A5%BC-%EC%9D%B4%EC%9A%A9%ED%95%9C-Object-detection

# %% [markdown]
# # Yolov5

# %%
# !pwd
# !git clone https://github.com/ultralytics/yolov5
# !pip install -r ./yolov5/requirements.txt
# Out:
# /Users/jacob/Documents/workspacetf/project_1
# 'yolov5'에 복제합니다...
# remote: Enumerating objects: 14765, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 14765 (delta 53), reused 74 (delta 40), pack-reused 14669
# 오브젝트를 받는 중: 100% (14765/14765), 13.54 MiB | 9.20 MiB/s, 완료.
# 델타를 알아내는 중: 100% (10192/10192), 완료.

# %%
import yaml

path = './car_data/car_label/yaml/data.yaml'
with open(path, 'r') as f : 
    data = yaml.load(f, Loader=yaml.FullLoader) 
    data['train'] = '/Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/train/images'
    data['val'] = '/Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/valid/images'
    data['nc'] = 1 
    data['names'] = ['tire'] #class names

    with open(path, 'w')  as f: 
        yaml.dump(data, f)
        print(data)
# Out:
# {'names': ['tire'], 'nc': 1, 'path': '../datasets/roboflow', 'test': 'test/images', 'train': '/Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml2/train/images', 'val': '/Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml2/valid/images'}

# %%
# !ls ./car_data/car_label/yaml2
# Out:
# README.dataset.txt  data.yaml           train
# README.roboflow.txt test                valid

# %%
# !ls ./yolov5/models
# Out:
# __init__.py     experimental.py tf.py           yolov5m.yaml    yolov5x.yaml
# __pycache__     hub             yolo.py         yolov5n.yaml
# common.py       segment         yolov5l.yaml    yolov5s.yaml

# %%
#이미지와 라벨이 매칭 되는지 확인 
# !ls car_data/car_label/yaml/train/images | head -4
print()
# !ls car_data/car_label/yaml/train/labels | head -4
# Out:
# 1--1-_png.rf.49e26e46b9fc5e17bd8a91656c2a8e9e.jpg
# 1--1-_png.rf.fb313d8418bcbb54145145dba3eef4a5.jpg
# 1--10-_jpg.rf.8eab3c9e7589f85e116452c07e36dd70.jpg
# 1--10-_jpg.rf.b5252fdbc74c9de7bcc38561b98a190f.jpg
#
# 1--1-_png.rf.49e26e46b9fc5e17bd8a91656c2a8e9e.txt
# 1--1-_png.rf.fb313d8418bcbb54145145dba3eef4a5.txt
# 1--10-_jpg.rf.8eab3c9e7589f85e116452c07e36dd70.txt
# 1--10-_jpg.rf.b5252fdbc74c9de7bcc38561b98a190f.txt

# %%
# !cat car_data/car_label/yaml/train/labels/1--1-_png.rf.49e26e46b9fc5e17bd8a91656c2a8e9e.txt
# !cat car_data/car_label/yaml/train/labels/1--1-_png.rf.fb313d8418bcbb54145145dba3eef4a5.txt
# Out:
# 164 621 300 621 300 753 164 753 tire 0
# 716 621 848 621 848 752 716 752 tire 0724 271 860 271 860 403 724 403 tire 0
# 176 273 308 273 308 404 176 404 tire 0

# %%
# !ls car_data/car_label/yaml
# Out:
# README.dataset.txt  data.yaml           train
# README.roboflow.txt test                valid

# %% [markdown]
# <br><br><br>
#
# https://github.com/ultralytics/yolov5/wiki/Train-Custom-Data참고<br>
# --img : 이미지 크기<br>
# --batch : 배치 킉<br>
# --epochs : 학습횟수<br>
# --data : yaml파일<br>
# --cfg : 모델선택 모델의 크기에 따라 yolov5l.yaml,yolov5m.yaml,yolov5s.yaml,yolov5x.yaml 등이 있음<br>
# --weights : pre-tarined model(전이학습)의 가중치 선택<br>
# <br>
# *전이학습(pre-tarined model)이란?<br>
# https://jeinalog.tistory.com/13<br>
# --name : 결과 저장할 폴더<br>
#
# <br><br><br>

# %%
# Path yaml
# !python ./yolov5/train.py --img 640 --batch 16 --epochs 20 --data ./car_data/car_label/yaml/data.yaml --cfg ./yolov5/models/yolov5s.yaml --weights yolov5s.pt --name yolov5_coco
# Out:
# train: weights=yolov5s.pt, cfg=./yolov5/models/yolov5s.yaml, data=./car_data/car_label/yaml/data.yaml, hyp=yolov5/data/hyps/hyp.scratch-low.yaml, epochs=20, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=None, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=yolov5/runs/train, name=yolov5_coco, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# YOLOv5 🚀 v6.2-237-g55e9516 Python-3.8.13 torch-1.13.0 CPU
#
# hyperparameters: lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=0.05, cls=0.5, cls_pw=1.0, obj=1.0, obj_pw=1.0, iou_t=0.2, anchor_t=4.0, fl_gamma=0.0, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, mosaic=1.0, mixup=0.0, copy_paste=0.0
# ClearML: run 'pip install clearml' to automatically track, visualize and remotely train YOLOv5 🚀 in ClearML
# Comet: run 'pip install comet_ml' to automatically track and visualize YOLOv5 🚀 runs in Comet
# TensorBoard: Start with 'tensorboard --logdir yolov5/runs/train', view at http://localhost:6006/
# Overriding model.yaml nc=80 with nc=1
#
#                  from  n    params  module                                  arguments
#   0                -1  1      3520  models.common.Conv                      [3, 32, 6, 2, 2]
#   1                -1  1     18560  models.common.Conv                      [32, 64, 3, 2]
#   2                -1  1     18816  models.common.C3                        [64, 64, 1]
#   3                -1  1     73984  models.common.Conv                      [64, 128, 3, 2]
#   4                -1  2    115712  models.common.C3                        [128, 128, 2]
#   5                -1  1    295424  models.common.Conv                      [128, 256, 3, 2]
#   6                -1  3    625152  models.common.C3                        [256, 256, 3]
#   7                -1  1   1180672  models.common.Conv                      [256, 512, 3, 2]
#   8                -1  1   1182720  models.common.C3                        [512, 512, 1]
#   9                -1  1    656896  models.common.SPPF                      [512, 512, 5]
#  10                -1  1    131584  models.common.Conv                      [512, 256, 1, 1]
#  11                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  12           [-1, 6]  1         0  models.common.Concat                    [1]
#  13                -1  1    361984  models.common.C3                        [512, 256, 1, False]
#  14                -1  1     33024  models.common.Conv                      [256, 128, 1, 1]
#  15                -1  1         0  torch.nn.modules.upsampling.Upsample    [None, 2, 'nearest']
#  16           [-1, 4]  1         0  models.common.Concat                    [1]
#  17                -1  1     90880  models.common.C3                        [256, 128, 1, False]
#  18                -1  1    147712  models.common.Conv                      [128, 128, 3, 2]
#  19          [-1, 14]  1         0  models.common.Concat                    [1]
#  20                -1  1    296448  models.common.C3                        [256, 256, 1, False]
#  21                -1  1    590336  models.common.Conv                      [256, 256, 3, 2]
#  22          [-1, 10]  1         0  models.common.Concat                    [1]
#  23                -1  1   1182720  models.common.C3                        [512, 512, 1, False]
#  24      [17, 20, 23]  1     16182  models.yolo.Detect                      [1, [[10, 13, 16, 30, 33, 23], [30, 61, 62, 45, 59, 119], [116, 90, 156, 198, 373, 326]], [128, 256, 512]]
# YOLOv5s summary: 214 layers, 7022326 parameters, 7022326 gradients, 15.9 GFLOPs
#
# Transferred 342/349 items from yolov5s.pt
# optimizer: SGD(lr=0.01) with parameter groups 57 weight(decay=0.0), 60 weight(decay=0.0005), 60 bias
# train: Scanning '/Users/jacob/Documents/workspacetf/project_1/car_data/car_label
# val: Scanning '/Users/jacob/Documents/workspacetf/project_1/car_data/car_label/y
#
# AutoAnchor: 5.95 anchors/target, 1.000 Best Possible Recall (BPR). Current anchors are a good fit to dataset ✅
# Plotting labels to yolov5/runs/train/yolov5_coco4/labels.jpg...
# Image sizes 640 train, 640 val
# Using 8 dataloader workers
# Logging results to yolov5/runs/train/yolov5_coco4
# Starting training for 20 epochs...
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        0/19         0G     0.1116    0.03727          0         38        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 1.500s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.005      0.225    0.00563    0.00122
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        1/19         0G    0.08923    0.03878          0         50        640: 1
#                  Class     Images  Instances          P          R      mAP50   WARNING ⚠️ NMS time limit 1.500s exceeded
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.299       0.15      0.162     0.0554
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        2/19         0G    0.07628     0.0374          0         42        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40        0.3      0.643      0.271      0.077
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        3/19         0G    0.06991    0.03074          0         49        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.695       0.74      0.789      0.254
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        4/19         0G    0.06778     0.0263          0         37        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.621       0.85      0.667       0.18
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        5/19         0G    0.06245    0.02525          0         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.334        0.9      0.489      0.184
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        6/19         0G    0.05971    0.02392          0         40        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.768      0.725      0.847      0.396
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        8/19         0G    0.05992    0.02079          0         40        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.794      0.775      0.876      0.365
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#        9/19         0G    0.05449    0.02063          0         43        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.675      0.778      0.846      0.316
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       10/19         0G     0.0476    0.02005          0         35        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.696      0.925      0.782      0.302
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       11/19         0G    0.04909    0.01682          0         48        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.859      0.925      0.952      0.384
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       12/19         0G    0.04018    0.01777          0         48        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.925       0.95      0.967      0.661
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       13/19         0G    0.03953    0.01737          0         52        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.996          1      0.995      0.713
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       14/19         0G    0.03477    0.01562          0         45        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.846       0.95       0.97      0.575
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       15/19         0G    0.03319    0.01425          0         51        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.997          1      0.995      0.746
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       16/19         0G    0.02953     0.0148          0         37        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.997          1      0.995      0.734
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       17/19         0G    0.02854    0.01345          0         41        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.997          1      0.995      0.717
#
#       Epoch    GPU_mem   box_loss   obj_loss   cls_loss  Instances       Size
#       19/19         0G    0.02455    0.01444          0         46        640: 1
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.997          1      0.995      0.835
#
# 20 epochs completed in 0.571 hours.
# Optimizer stripped from yolov5/runs/train/yolov5_coco4/weights/last.pt, 14.4MB
# Optimizer stripped from yolov5/runs/train/yolov5_coco4/weights/best.pt, 14.4MB
#
# Validating yolov5/runs/train/yolov5_coco4/weights/best.pt...
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
#                  Class     Images  Instances          P          R      mAP50
#                    all         20         40      0.997          1      0.995      0.835
# Results saved to yolov5/runs/train/yolov5_coco4

# %% [markdown]
# Results saved to yolov5/runs/train/yolov5_coco4

# %%
#/content/yolov5/runs/train/yolov5_coco 의 train_batch0.jpg 를 보면 잘 인식되나 확인할 수 있다.

# %%
# !ls yolov5/runs/train/yolov5_coco4/weights
#가장 성능이 좋았던 모델, 마지막 모델 두개 저장됨.
# Out:
# best.pt last.pt

# %%
# !ls /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images
# Out:
# 1--1-_jpg.rf.521367355a86693b83c2ac56c28457e0.jpg
# 1--20-_jpg.rf.41c4b68125ad6f990ad35927deb17070.jpg
# 1--26-_jpg.rf.0dbb2b50aa543661ecf192814bc398c9.jpg
# 1--28-_jpg.rf.25d72fca8e5196a779c140fd632d2812.jpg
# 1--32-_jpg.rf.5663700e0655182baf8340b897d8ad8d.jpg
# 1--34-_jpg.rf.442637eb7c9c95f2ef7987274eca8877.jpg
# 1--44-_jpg.rf.9561dcaa9c0239e70da2740ad9b88dba.jpg
# 1--52-_jpg.rf.8525347e4c3711600ebbaeda5f047a20.jpg
# 1--68-_jpg.rf.7ebf0e4cc664281672b7689bec27ba40.jpg
# 1--71-_jpg.rf.6ac52e828efc404468bc5fc85fb04aa8.jpg

# %%
#conf -> 정확도 설정
# !python yolov5/detect.py --weights yolov5/runs/train/yolov5_coco4/weights/best.pt --img 640 --conf 0.4 --source /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images
# Out:
# detect: weights=['yolov5/runs/train/yolov5_coco4/weights/best.pt'], source=/Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-237-g55e9516 Python-3.8.13 torch-1.13.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/10 /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images/1--1-_jpg.rf.521367355a86693b83c2ac56c28457e0.jpg: 640x640 3 tires, 97.2ms
# image 2/10 /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images/1--20-_jpg.rf.41c4b68125ad6f990ad35927deb17070.jpg: 640x640 2 tires, 93.4ms
# image 3/10 /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images/1--26-_jpg.rf.0dbb2b50aa543661ecf192814bc398c9.jpg: 640x640 2 tires, 92.6ms
# image 4/10 /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images/1--28-_jpg.rf.25d72fca8e5196a779c140fd632d2812.jpg: 640x640 2 tires, 93.0ms
# image 5/10 /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images/1--32-_jpg.rf.5663700e0655182baf8340b897d8ad8d.jpg: 640x640 2 tires, 95.0ms
# image 6/10 /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images/1--34-_jpg.rf.442637eb7c9c95f2ef7987274eca8877.jpg: 640x640 2 tires, 91.0ms
# image 7/10 /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images/1--44-_jpg.rf.9561dcaa9c0239e70da2740ad9b88dba.jpg: 640x640 2 tires, 94.6ms
# image 8/10 /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images/1--52-_jpg.rf.8525347e4c3711600ebbaeda5f047a20.jpg: 640x640 3 tires, 91.8ms
# image 9/10 /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images/1--68-_jpg.rf.7ebf0e4cc664281672b7689bec27ba40.jpg: 640x640 2 tires, 93.5ms
# image 10/10 /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images/1--71-_jpg.rf.6ac52e828efc404468bc5fc85fb04aa8.jpg: 640x640 2 tires, 93.8ms
# Speed: 0.5ms pre-process, 93.6ms inference, 0.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp2

# %%
import glob
import random
from IPython.display import Image,display

image_name=random.choice(glob.glob('yolov5/runs/detect/exp2/*.jpg'))
display(Image(filename=image_name))

# %%
# !ls yolov5/runs/detect/exp2
# Out:
# 1--1-_jpg.rf.521367355a86693b83c2ac56c28457e0.jpg
# 1--20-_jpg.rf.41c4b68125ad6f990ad35927deb17070.jpg
# 1--26-_jpg.rf.0dbb2b50aa543661ecf192814bc398c9.jpg
# 1--28-_jpg.rf.25d72fca8e5196a779c140fd632d2812.jpg
# 1--32-_jpg.rf.5663700e0655182baf8340b897d8ad8d.jpg
# 1--34-_jpg.rf.442637eb7c9c95f2ef7987274eca8877.jpg
# 1--44-_jpg.rf.9561dcaa9c0239e70da2740ad9b88dba.jpg
# 1--52-_jpg.rf.8525347e4c3711600ebbaeda5f047a20.jpg
# 1--68-_jpg.rf.7ebf0e4cc664281672b7689bec27ba40.jpg
# 1--71-_jpg.rf.6ac52e828efc404468bc5fc85fb04aa8.jpg

# %%
all_image_files = glob.glob('yolov5/runs/detect/exp2/*.jpg')
display(Image(filename=all_image_files[8]))

# %% [markdown]
# 1.학습 할 수 있는 데이터가 부족한 것 같음.<br>
# -> imgaug 라이브러리를 사용해서 증강해보는 것이 좋을 것 같으나, 현재 프로젝트주 스케쥴에 맞춰 진행해야하므로 데이터증강은 제외<br>
# 2.현재 모델 사용해서 영역 자르기.

# %%
# !ls yolov5/runs/detect/
# Out:
# exp  exp2

# %% [markdown]
# # Service

# %% [markdown]
# - https://bong-sik.tistory.com/30

# %%
#image upload (Front Upload Form -> /Users/jacob/Documents/workspacetf/project_1/car_data/upload)

# %%
# !ls /Users/jacob/Documents/workspacetf/project_1/car_data/upload
# Out:
# 25197D3D57231E321D.jpg img.jpg
# 99F0333359AE58A622.jpg tire_1.jpg

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/yolov5_coco4/weights/best.pt --img 640 --conf 0.85 --source /Users/jacob/Documents/workspacetf/project_1/car_data/car_label/yaml/test/images
# !python yolov5/detect.py --weights yolov5/runs/train/yolov5_coco4/weights/best.pt --img 640 --conf 0.2 --source /Users/jacob/Documents/workspacetf/project_1/car_data/upload
# Out:
# detect: weights=['yolov5/runs/train/yolov5_coco4/weights/best.pt'], source=/Users/jacob/Documents/workspacetf/project_1/car_data/upload, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-237-g55e9516 Python-3.8.13 torch-1.13.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /Users/jacob/Documents/workspacetf/project_1/car_data/upload/tire_1.jpg: 448x640 (no detections), 69.1ms
# Speed: 0.4ms pre-process, 69.1ms inference, 0.2ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp5

# %%
all_image_files = glob.glob('yolov5/runs/detect/exp5/*.jpg')
print(all_image_files)
display(Image(filename=all_image_files[0]))
# Out:
# ['yolov5/runs/detect/exp5/tire_1.jpg']

# %%
# !python yolov5/detect.py --weights yolov5/runs/train/yolov5_coco4/weights/best.pt --img 640 --conf 0.2 --source /Users/jacob/Documents/workspacetf/project_1/car_data/upload/img.jpg
# Out:
# detect: weights=['yolov5/runs/train/yolov5_coco4/weights/best.pt'], source=/Users/jacob/Documents/workspacetf/project_1/car_data/upload/img.jpg, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.2, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v6.2-237-g55e9516 Python-3.8.13 torch-1.13.0 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /Users/jacob/Documents/workspacetf/project_1/car_data/upload/img.jpg: 448x640 2 tires, 67.2ms
# Speed: 0.4ms pre-process, 67.2ms inference, 0.5ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp6

# %%
all_image_files = glob.glob('yolov5/runs/detect/exp6/*.jpg')
print(all_image_files)
display(Image(filename=all_image_files[0]))
# Out:
# ['yolov5/runs/detect/exp6/img.jpg']

# %% [markdown]
# - https://www.semanticscholar.org/paper/Vehicle-tire-(tyre)-detection-and-text-recognition-Kazmi-Nabney/b26fa896d49546645447c6a03ec5766a27922a89/figure/5
# - https://blog.griddynamics.com/how-to-identify-vehicle-tires-using-deep-learning-visual-models/
